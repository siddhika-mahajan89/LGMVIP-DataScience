# %% [markdown]
# ## Let's Grow More VIP
# ## Beginner Level Task 04
# ## Image to Pencil Sketch with Python
# ## Name: Siddhika Vijay Mahajan

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo'

# %%
os.chdir("E:\Wallpaper")

# %%
img=cv2.imread("Flower.jpg")
plt.imshow(img)

# %%
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=720x1520 at 0x1EB497B4A88>

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_img))
# Out:
# <PIL.Image.Image image mode=L size=720x1520 at 0x1EB499CA088>

# %%
inv_gray_img = 255-gray_img

# %%
inv_gray_img
# Out:
# array([[254, 254, 254, ..., 255, 255, 255],
#        [253, 253, 253, ..., 253, 253, 253],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254]], dtype=uint8)

# %%
display(Image.fromarray(inv_gray_img))
# Out:
# <PIL.Image.Image image mode=L size=720x1520 at 0x1EB499CE508>

# %%
blur_img=cv2.GaussianBlur(inv_gray_img, (35,35),0)

# %%
display(Image.fromarray(blur_img))
# Out:
# <PIL.Image.Image image mode=L size=720x1520 at 0x1EB49C11848>

# %%
img=255-blur_img
def dodge(gray_imablur_img):
    return cv2.divide(gray_img, img, scale = 400.0)

# %%
pencil_sketch=dodge(img)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=720x1520 at 0x1EB49C15688>
